# %%
import config
import requests
import bs4 as bs
import argparse
import pandas as pd
import random
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
class RapGetter():

	_df = pd.DataFrame(columns = ['Artist', 'Album', 'Song', 'Text', 'Commas', 'Question Marks', 'Unique Words'])

	def __init__(self, url):
		# for markov?
		self.original_text = ''

		self.url = url
		self.queries = []
		self.wordcloud_count = 10

		self.artist = re.search(r'albums\/(.*?)\/', url).group(1)
		self.album = re.search(r'.+(\/.+)$', url).group(1)
		self.song_titles = []
		self.word_list = []
		self.commas_list = []
		self.question_marks_list = []
		self.unique_words = []

	def fetch(self):

		# get all songs
		response = requests.get(self.url)
		soup = bs.BeautifulSoup(response.text, features="html.parser")
		list_of_songs = soup.find_all(class_='chart_row chart_row--light_border chart_row--full_bleed_left chart_row--align_baseline chart_row--no_hover')
		counter = 0
		for i in list_of_songs:
			list_of_songs[counter] = i.find(class_='chart_row-content').find('a').get('href')
			counter = counter + 1
		final_list_of_songs = []

		# remove skits from analysis
		for i in list_of_songs:
			if 'skit' not in i:
				final_list_of_songs.append(i)
		self.queries = final_list_of_songs


	def clean(self):
		
		for query in self.queries:
		
			response = requests.get(query)
			soup = bs.BeautifulSoup(response.text, features="html.parser")

			# find song title here
			song_title = soup.find(class_='header_with_cover_art-primary_info-title').text
			self.song_titles.append(song_title)

			text = soup.find(class_='lyrics').get_text()

			# remove words between [] in text, which stores metadata on the song
			text = re.sub('\[[^\]]*]', '', text).strip()

			# store original datal, untouched
			if self.original_text == '':
				self.original_text = self.original_text + text
			else:
				self.original_text = self.original_text + " " + text

			# clean strings
			text = text.replace('\n', ' ').lower().strip()
			
			text = re.sub('[\(\)\'!]', '', text).strip()

			text = text.split(",")
			s = ''
			self.commas_list.append(len(text) - 1)
			text = s.join(text).lower().strip()

			text = text.split("?")
			s = ''
			self.question_marks_list.append(len(text) - 1)
			text = s.join(text).lower().strip()

			text = re.sub('\s\s+', ' ', text)
			self.word_list.append(text)

	# make method to call markov model

	def print_info(self):
		print(self.original_text[0])

	def print_word_list(self):
		print(self.word_list)
        
	def count_unique_words(self):
		for song in self.word_list:
			lyrics = song.split(" ")
			set_ = set()
			for word in lyrics:
				set_.add(word)
			arr = []
			for i in set_:
				arr.append(i)
			self.unique_words.append(arr)

	def filter_wordcloud_by_size(self, store, n):
		word_appears_more_than_n_times = []
		for i in store:
			if store[i] > n:
				word_appears_more_than_n_times.append(i)

		return word_appears_more_than_n_times


	# can i break this up?
	# need to make wordcloud per song, per album, and per artist?
	def wordcloud(self):
		# count number of unique variables
		# should i just do this in the dataframe?
		store = {}
		for i in self.word_list.split(" "):
			if i in store:
				store[i] = store[i] + 1
			else:
				store[i] = 1

		word_appears_more_than_n_times = filter_wordcloud_by_size(store, self.wordcloud_count)

		potentially_often_used_rap_words_and_common_words = ["nigga", "uh", "yeah", "shit", "niggas", "fuck", "fuckin'", "uhh", "ayy", "the"]
		set_ = set()
		for i in word_appears_more_than_n_times:
			if i not in potentially_often_used_rap_words_and_common_words:
				set_.add(i)

		wordcloud_text = ""
		for i in set_:
			wordcloud_text = wordcloud_text + " " + i
		cloud = WordCloud(background_color="white").generate(wordcloud_text)
		plt.imshow(cloud)
		plt.axis("off")
		plt.show()

	# @classmethod
	# def dataframe(cls):
	# 	return 

	# this is incorrect, i want to be able to create a dataframe and append things to it :/
	# ask for help
	def dataframe(self):
		for i in range(len(self.word_list)):
			RapGetter._df = RapGetter._df.append({
				'Artist': self.artist, 
				'Text': self.word_list[i],
				'Album': self.album,
				'Song': self.song_titles[i],
				'Commas': self.commas_list[i],
				'Question Marks': self.question_marks_list[i],
                'Unique Words': self.unique_words[i]
				}, ignore_index=True)
		return RapGetter._df

# %%
url_list = [
	'https://genius.com/albums/Chance-the-rapper/Coloring-book',
	'https://genius.com/albums/Ybn-cordae/The-lost-boy',
]

for url in url_list:
	lyrics = RapGetter(url)
	lyrics.fetch()
	lyrics.clean()
	lyrics.count_unique_words()
	lyrics.dataframe()
    
print(RapGetter._df)
# Out:
#         Artist          Album                 Song  \
# 0   Ybn-cordae  /The-lost-boy           Wintertime
# 1   Ybn-cordae  /The-lost-boy           Have Mercy
# 2   Ybn-cordae  /The-lost-boy             Bad Idea
# 3   Ybn-cordae  /The-lost-boy         Thanksgiving
# 4   Ybn-cordae  /The-lost-boy                  RNP
# 5   Ybn-cordae  /The-lost-boy        Broke As Fuck
# 6   Ybn-cordae  /The-lost-boy       Thousand Words
# 7   Ybn-cordae  /The-lost-boy        Way Back Home
# 8   Ybn-cordae  /The-lost-boy          Been Around
# 9   Ybn-cordae  /The-lost-boy  Nightmares Are Real
# 10  Ybn-cordae  /The-lost-boy       Family Matters
# 11  Ybn-cordae  /The-lost-boy       We Gon Make It
# 12  Ybn-cordae  /The-lost-boy         Lost & Found
#
#                                                  Text Commas Question Marks  \
# 0   uh okay we all got skeletons in our closet fro...     38              0
# 1   kid ugh sweet lord please have mercy baby jesu...     52              1
# 2   ooh ooh yeah uh bongo bytheway i know myself a...     65              4
# 3   its perfect okay mac and cheese up in the oven...     37              3
# 4   one of yall niggas gon be fuckin with me i got...     37              5
# 5   uh yeah daytrip took it to ten hey i was broke...     52              2
# 6   uh they say a pictures worth a thousand words ...     42              2
# 7   uh you can be who you want to be but rather be...     55              2
# 8   when you when you was in chicago still did you...     31              1
# 9   okay uh i can tell you how i first started in ...     57              4
# 10  uh i got an auntie who be raisin her daughters...     30              0
# 11  yeah god bless the dreamchasers if you got a d...     75              5
# 12  switch up my lifestyle yup yup uh huh yeah i w...     38              1
#
#                                          Unique Words
# 0   [sniper, nice, eighty, okay, swag, where, to, ...
# 1   [comin, here, bad, where, smell, stay, to, tok...
# 2   [kool-aid, ever, performed, soundin, syrup, he...
# 3   [didnt, here, plus, cousins, where, okay, stay...
# 4   [nosebleeds, healthy, fit, wealthy, bad, smell...
# 5   [didnt, bad, to, sippin, attack, got, fendi, b...
# 6   [stuck, woke, purpose, village, to, things, hu...
# 7   [woke, bad, where, okay, to, annie, put, day, ...
# 8   [carrying, dope, awful, bad, cousins, fifth, t...
# 9   [doodles, pack, homies, okay, started, stay, t...
# 10  [catalyst, verse, comin, here, raisin, soul, t...
# 11  [lose, ever, didnt, here, bad, line, okay, to,...
# 12  [smith, writtens, bad, where, studio, skippin,...

# %%
RapGetter._df[RapGetter._df['Artist'].str.match('Chance-the-rapper')]
# Out:
#                Artist           Album                    Song  \
# 0   Chance-the-rapper  /Coloring-book              All We Got
# 1   Chance-the-rapper  /Coloring-book              No Problem
# 2   Chance-the-rapper  /Coloring-book          Summer Friends
# 3   Chance-the-rapper  /Coloring-book  D.R.A.M. Sings Special
# 4   Chance-the-rapper  /Coloring-book               Blessings
# 5   Chance-the-rapper  /Coloring-book              Same Drugs
# 6   Chance-the-rapper  /Coloring-book                 Mixtape
# 7   Chance-the-rapper  /Coloring-book                  Angels
# 8   Chance-the-rapper  /Coloring-book                Juke Jam
# 9   Chance-the-rapper  /Coloring-book               All Night
